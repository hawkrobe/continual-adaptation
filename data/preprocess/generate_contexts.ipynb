# %%
import matplotlib
matplotlib.use('Agg')

import visualize_contexts as viz
import generate_hard_contexts as gen
import pandas as pd
# %matplotlib inline
from importlib import reload

# %%
reload(gen)
gen.make_contexts('coco', context_type="easy")
#gen.make_contexts('vgg')

# %%
reload(viz)
viz.plot_contexts('coco', context_type="easy")
#viz.plot_contexts('vgg')

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
for i in range(20):
    img=mpimg.imread('gallery/coco_easy/context_{}.jpg'.format(i))
    imgplot = plt.imshow(img)
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
